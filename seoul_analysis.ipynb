# %%
# 이거 실행한 다음에 좌측 상단 '런타임 - 런타임 다시 시작' 을 클릭하여 런타임을 재시작해주세요! (plt 한글깨짐 방지)
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 1s (14.4 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
#나눔폰트사용
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic') 
plt.rcParams['axes.unicode_minus'] = False

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
seoul_parking = pd.read_csv('/content/drive/MyDrive/unite/data/서울시구별주차장2021.csv')
seoul_parking.head()
# Out:
# Mounted at /content/drive
#     구별  합계(개소)   합계(면수)  노상(개소)  노상(면수)  노외(개소)  노외(면수)  건축물부설(개소)  건축물부설(면수)
# 0   소계  314440  4354516   10836  107530    1956  106862     301648    4140124
# 1  종로구    7187    96350     151    2095     107    6119       6929      88136
# 2   중구    4294   108561     139    1228      72    5995       4083     101338
# 3  용산구    7434   110649     353    3474      64    3481       7017     103694
# 4  성동구    6671   134107     237    4495      73    3667       6361     125945

# %%
import matplotlib.pyplot as plt
import numpy as np

seoul_parking_1 = seoul_parking.set_index('구별')
seoul_parking_1 = seoul_parking_1.iloc[1:]

plt.figure(figsize=(25,10))
plt.title('서울시 구별 주차장', size=20)

index = np.arange(seoul_parking_1.shape[0])
w = 0.4

plt.bar(index - w, seoul_parking_1['합계(개소)'], width=w, label='주차장수')
plt.bar(index, seoul_parking_1['합계(면수)'], width=w, label='주차장칸수')

plt.legend()
plt.xticks(index, seoul_parking_1.index)
plt.show()

# %%
'''
seoul_parking_sort1 = seoul_parking_1[['노상(개소)','노외(개소)', '건축물부설(개소)']]

plt.figure(figsize=(25,10))
plt.title('서울시 구별 특정 주차장 개수', size=20)

index = np.arange(seoul_parking_sort1.shape[0])
w = 0.3

plt.bar(index - w, seoul_parking_sort1['노상(개소)'], width=w, label='노상')
plt.bar(index, seoul_parking_sort1['노외(개소)'], width=w, label='노외')
plt.bar(index+w, seoul_parking_sort1['건축물부설(개소)'], width=w, label='건축물부설')

plt.legend()
plt.xticks(index, seoul_parking_sort1.index)
plt.show()
'''
# Out:
# "\nseoul_parking_sort1 = seoul_parking_1[['노상(개소)','노외(개소)', '건축물부설(개소)']]\n\nplt.figure(figsize=(25,10))\nplt.title('서울시 구별 특정 주차장 개수', size=20)\n\nindex = np.arange(seoul_parking_sort1.shape[0])\nw = 0.3\n\nplt.bar(index - w, seoul_parking_sort1['노상(개소)'], width=w, label='노상')\nplt.bar(index, seoul_parking_sort1['노외(개소)'], width=w, label='노외')\nplt.bar(index+w, seoul_parking_sort1['건축물부설(개소)'], width=w, label='건축물부설')\n\nplt.legend()\nplt.xticks(index, seoul_parking_sort1.index)\nplt.show()\n"

# %%
pip install squarify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
seoul_parking_sort2 = seoul_parking_1[['노상(면수)','노외(면수)', '건축물부설(면수)']]

plt.figure(figsize=(25,10))
plt.title('서울시 구별 특정 주차장 면수', size=20)

index = np.arange(seoul_parking_sort2.shape[0])
w = 0.3

plt.bar(index - w, seoul_parking_sort2['노상(면수)'], width=w, label='노상')
plt.bar(index, seoul_parking_sort2['노외(면수)'], width=w, label='노외')
plt.bar(index+w, seoul_parking_sort2['건축물부설(면수)'], width=w, label='건축물부설')

plt.legend()
plt.xticks(index, seoul_parking_sort2.index)
plt.show()

# %%
import squarify
plt.figure(figsize=(13, 7))
plt.title('건물 부설 주차 면수가 많은 자치구 Top5', fontsize = 30)
seoul_parking_sort2 = seoul_parking_sort2.sort_values(by=['건축물부설(면수)'], ascending=False)
squarify.plot(seoul_parking_sort2['건축물부설(면수)'][0:5], label=seoul_parking_sort2.index, text_kwargs={'fontsize':20})

# %%
plt.figure(figsize=(13, 7))
plt.title('노상 주차 면수가 많은 자치구 Top5', fontsize = 30)
seoul_parking_sort2 = seoul_parking_sort2.sort_values(by=['노상(면수)'], ascending=False)
squarify.plot(seoul_parking_sort2['노상(면수)'][0:5], label=seoul_parking_sort2.index, text_kwargs={'fontsize':20})

# %%
plt.figure(figsize=(13, 7))
plt.title('노외 주차 면수가 많은 자치구 Top5', fontsize = 30)
seoul_parking_sort2 = seoul_parking_sort2.sort_values(by=['노외(면수)'], ascending=False)
squarify.plot(seoul_parking_sort2['노외(면수)'][0:5], label=seoul_parking_sort2.index, text_kwargs={'fontsize':20})

# %%
seoul_parking_sort2 = seoul_parking_1[['노상(면수)','노외(면수)', '건축물부설(면수)']]

plt.figure(figsize=(25,10))
plt.title('서울시 구별 특정 주차장 면수', size=20)

index = np.arange(seoul_parking_sort2.shape[0])
w = 0.3

plt.bar(index - w, seoul_parking_sort2['노상(면수)'], width=w, label='노상')
plt.bar(index, seoul_parking_sort2['노외(면수)'], width=w, label='노외')

plt.legend()
plt.xticks(index, seoul_parking_sort2.index)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
seoul_parking_2 = pd.read_csv('/content/drive/MyDrive/unite/data/서울시주차장확보율2021.csv')
seoul_parking_3 = pd.read_csv('/content/drive/MyDrive/unite/data/서울시구별주민등록인구.csv')
seoul_parking_2.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   자치구별  자동차등록대수     주차면수  주차장확보율
# 0   소계  3176736  4354516   137.0
# 1  종로구    50347    96350   191.0
# 2   중구    61159   108561   178.0
# 3  용산구    79740   110649   139.0
# 4  성동구   107564   134107   125.0

# %%
seoul_parking_car = seoul_parking_2.iloc[1:]
seoul_num = seoul_parking_3.iloc[1:]
seoul_num = seoul_num[['동별','계']]
seoul_num.columns = ['자치구별', '인구수']
seoul_parking_numcar = pd.merge(seoul_parking_car, seoul_num, on='자치구별')
seoul_parking_numcar
# Out:
#     자치구별  자동차등록대수    주차면수  주차장확보율     인구수
# 0    종로구    50347   96350   191.0  153789
# 1     중구    61159  108561   178.0  131787
# 2    용산구    79740  110649   139.0  237285
# 3    성동구   107564  134107   125.0  292672
# 4    광진구    98371  137040   139.0  352627
# 5   동대문구    98466  148063   150.0  352006
# 6    중랑구   114375  133919   117.1  391885
# 7    성북구   121073  155093   128.1  440142
# 8    강북구    75337   93845   125.0  302563
# 9    도봉구    95631  111916   117.0  319373
# 10   노원구   152285  183901   121.0  514946
# 11   은평구   133175  166662   125.1  477173
# 12  서대문구    89200  125844   141.0  315659
# 13   마포구   121363  182861   151.0  378686
# 14   양천구   151338  168382   111.0  450487
# 15   강서구   205058  288042   140.5  579768
# 16   구로구   145874  190319   130.0  421163
# 17   금천구    90169  133132   148.0  244891
# 18  영등포구   146095  183911   126.0  400908
# 19   동작구   106229  139766   132.0  394364
# 20   관악구   118083  153306   130.0  499449
# ...

# %%
seoul_parking_numcar['순확보율'] = (seoul_parking_numcar['주차장확보율'] - 100) * 0.01
seoul_parking_numcar['인구수관련주차장여유공간'] = seoul_parking_numcar['순확보율'] * seoul_parking_numcar['인구수']
seoul_parking_numcar
# Out:
#     자치구별  자동차등록대수    주차면수  주차장확보율     인구수   순확보율  인구수관련주차장여유공간
# 0    종로구    50347   96350   191.0  153789  0.910    139947.990
# 1     중구    61159  108561   178.0  131787  0.780    102793.860
# 2    용산구    79740  110649   139.0  237285  0.390     92541.150
# 3    성동구   107564  134107   125.0  292672  0.250     73168.000
# 4    광진구    98371  137040   139.0  352627  0.390    137524.530
# 5   동대문구    98466  148063   150.0  352006  0.500    176003.000
# 6    중랑구   114375  133919   117.1  391885  0.171     67012.335
# 7    성북구   121073  155093   128.1  440142  0.281    123679.902
# 8    강북구    75337   93845   125.0  302563  0.250     75640.750
# 9    도봉구    95631  111916   117.0  319373  0.170     54293.410
# 10   노원구   152285  183901   121.0  514946  0.210    108138.660
# 11   은평구   133175  166662   125.1  477173  0.251    119770.423
# 12  서대문구    89200  125844   141.0  315659  0.410    129420.190
# 13   마포구   121363  182861   151.0  378686  0.510    193129.860
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(25,10))
plt.title('서울시 인구수 관련 주차장 여유공간', size=20)

index = np.arange(seoul_parking_numcar.shape[0])
w = 0.5
plt.bar(index, seoul_parking_numcar['인구수관련주차장여유공간'], width=w, color = ['b'], alpha = 0.4, label='인구수관련주차장여유공간')

plt.legend()
plt.xticks(index, seoul_parking_numcar['자치구별'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(25,10))
plt.title('서울시 구별 인구수와 자동차등록대수', size=20)

index = np.arange(seoul_parking_numcar.shape[0])
w = 0.3

plt.bar(index-w, seoul_parking_numcar['자동차등록대수'], width=w, color = ['b'], alpha = 0.4, label='자동차수')
plt.bar(index,seoul_parking_numcar['인구수'], width=w, color = ['r'], alpha = 0.4, label='인구수')

plt.legend()
plt.xticks(index, seoul_parking_numcar['자치구별'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

seoul_parking_car = seoul_parking_2.iloc[1:]

plt.figure(figsize=(25,10))
plt.title('서울시 구별 주차장확보율', size=20)

index = np.arange(seoul_parking_car.shape[0])
w = 0.5

plt.bar(index, seoul_parking_car['주차장확보율'], width=w, color = ['g'], alpha = 0.5)

plt.legend()
plt.xticks(index, seoul_parking_car['자치구별'])
plt.ylim([100,200])
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
seoul_parking_4 = pd.read_csv('/content/drive/MyDrive/unite/data/현거주지별_서울_통근통학_인구(2020).csv')
seoul_parking_4 = seoul_parking_4[~seoul_parking_4['현거주지'].str.contains('계')]
seoul_parking_4 = seoul_parking_4[~seoul_parking_4['통근통학지'].str.contains('계')]
seoul_parking_4
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      현거주지  통근통학지  통근통학인구(12세 이상)
# 6   서울특별시  서울특별시         4756038
# 7   서울특별시  인천광역시           63345
# 8   서울특별시    경기도          523388
# 9   서울특별시     기타           35647
# 11  인천광역시  서울특별시          164282
# 12  인천광역시  인천광역시         1260878
# 13  인천광역시    경기도          182494
# 14  인천광역시     기타            5908
# 16    경기도  서울특별시         1255518
# 17    경기도  인천광역시          123173
# 18    경기도    경기도         5966491
# 19    경기도     기타           80652

# %%
seoul_commute_out = seoul_parking_4[(seoul_parking_4['현거주지']=='서울특별시')]
seoul_commute_out = seoul_commute_out[seoul_commute_out['통근통학지']!='서울특별시']
seoul_commute_out
# Out:
#     현거주지  통근통학지  통근통학인구(12세 이상)
# 7  서울특별시  인천광역시           63345
# 8  서울특별시    경기도          523388
# 9  서울특별시     기타           35647

# %%
seoul_commute_in = seoul_parking_4[(seoul_parking_4['통근통학지']=='서울특별시')]
seoul_commute_in
# Out:
#      현거주지  통근통학지  통근통학인구(12세 이상)
# 6   서울특별시  서울특별시         4756038
# 11  인천광역시  서울특별시          164282
# 16    경기도  서울특별시         1255518

# %%
seoul_parking_5 = pd.read_csv('/content/drive/MyDrive/unite/data/기타지역에서_서울통근통학지별.csv')
seoul_ex = seoul_parking_5.sum(axis=0)
seoul_ex = seoul_ex.to_frame()
seoul_ex = seoul_ex.T
seoul_ex.columns = ['현거주지', '통근통학지', '통근통학인구(12세 이상)']
seoul_ex.loc[0, '현거주지'] = '기타'
seoul_ex.loc[0, '통근통학지'] = '서울특별시'
seoul_ex
seoul_commute_inT = pd.concat([seoul_commute_in, seoul_ex])
seoul_commute_inT = seoul_commute_inT[seoul_commute_inT['현거주지']!='서울특별시']
seoul_commute_inT
# Out:
#      현거주지  통근통학지 통근통학인구(12세 이상)
# 11  인천광역시  서울특별시         164282
# 16    경기도  서울특별시        1255518
# 0      기타  서울특별시          16547

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(25,10))
plt.title('서울시 통근통학 인구수', size=30)

index = np.arange(seoul_commute_out.shape[0])
w = 0.3

plt.bar(index-w, seoul_commute_out['통근통학인구(12세 이상)'], width=w, color = ['b'], alpha = 0.4, label='서울에서 나가는 인구수')
plt.bar(index, seoul_commute_inT['통근통학인구(12세 이상)'], width=w, color = ['g'], alpha = 0.4, label='서울에 들어오는 인구수')

plt.legend(fontsize=25)
plt.xticks(index, seoul_commute_out['통근통학지'], fontsize=25)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
seoul_parking_6 = pd.read_csv('/content/drive/MyDrive/unite/data/서울경기인천교통수단별통근통학인구.csv')
seoul_parking_6 = seoul_parking_6.T
seoul_parking_6 = seoul_parking_6.rename(columns=seoul_parking_6.iloc[0])
seoul_parking_6 = seoul_parking_6.iloc[1:]
seoul_parking_6 = seoul_parking_6.rename_axis('교통수단').reset_index()
seoul_parking_6.iloc[0] = seoul_parking_6.iloc[0] + seoul_parking_6.iloc[1]
seoul_parking_6.iloc[2] = seoul_parking_6.iloc[2] + seoul_parking_6.iloc[3]
seoul_parking_6.iloc[4] = seoul_parking_6.iloc[4] + seoul_parking_6.iloc[5] + seoul_parking_6.iloc[6] + seoul_parking_6.iloc[7] + seoul_parking_6.iloc[8] + seoul_parking_6.iloc[9]
seoul_parking_6.drop([1,3,5,6,7,8,9,10], axis=0, inplace=True)
seoul_parking_6 = seoul_parking_6.set_index('교통수단')
seoul_parking_6.rename(index = {'걸어서자전거':'도보', '승용차승합차(벤)트럭' : '자가용',
                              '시내좌석마을버스통근통학차량고속시외버스전철지하철기차택시' : '대중교통',
                              '복합수단' : '복합수단'}, inplace=True)
seoul_parking_6
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         서울특별시   인천광역시      경기도
# 교통수단
# 도보    1074086  293559  1293669
# 자가용   1284924  724109  3469082
# 대중교통  2398582  499485  2176184
# 복합수단   569152   88728   451355

# %%
plt.figure(figsize=(7,7))

plt.title('서울시 통근통학 교통수단' , fontsize=20)
myexplode = [0, 0.1, 0, 0]
seoul_parking_6['서울특별시'].plot.pie(
                                        autopct = '%.1f%%' ,
                                         explode = myexplode,
                                        shadow = True,
                                         colors = ['lightblue', 'tomato','#ff9999', '#ffc000', '#8fd9b6', '#d395d0'] , 
                                         textprops = {'fontsize' : 12 , 
                                                      'weight' : 'bold'},
                                        wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5})
plt.show()

# %%
plt.figure(figsize=(7,7))

plt.title('경기도 통근통학 교통수단' , fontsize=20)
myexplode = [0, 0.1, 0, 0]

seoul_parking_6['경기도'].plot.pie(
                                        autopct = '%.1f%%' ,
                                        explode = myexplode,
                                        shadow = True,
                                         colors = ['lightblue', 'tomato','#ff9999', '#ffc000', '#8fd9b6', '#d395d0'] , 
                                         textprops = {'fontsize' : 12 , 
                                                      'weight' : 'bold'},
                                        wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5})
plt.show()

# %%
plt.figure(figsize=(7,7))

plt.title('인천광역시 통근통학 교통수단' , fontsize=20)
myexplode = [0, 0.1, 0, 0]

seoul_parking_6['인천광역시'].plot.pie(
                                        autopct = '%.1f%%' ,
                                    explode = myexplode,
                                    shadow = True,
                                         colors = ['lightblue', 'tomato','#ff9999', '#ffc000', '#8fd9b6', '#d395d0'] , 
                                         textprops = {'fontsize' : 12 , 
                                                      'weight' : 'bold'},
                                        wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5})
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(25,10))
plt.title('서울,인천,경기 교통수단별 통근통학 인구수', size=20)

index = np.arange(seoul_parking_6.shape[0])
w = 0.3

plt.bar(index-w, seoul_parking_6['서울특별시'], width=w, color = ['b'], alpha = 0.4, label='서울특별시')
plt.bar(index, seoul_parking_6['인천광역시'], width=w, color = ['g'], alpha = 0.4, label='인천광역시')
plt.bar(index+w, seoul_parking_6['경기도'], width=w, color = ['pink'], alpha = 0.4, label='경기도')

plt.legend()
plt.xticks(index, seoul_parking_6['교통수단'])
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
seoul_parking_7 = pd.read_csv('/content/drive/MyDrive/unite/data/서울시구별들어오는통근통학인구.csv')
seoul_parking_7.columns = [['구', '유입인구수']]
seoul_parking_8 = pd.read_csv('/content/drive/MyDrive/unite/data/서울시구별나가는통근통학인구.csv')
seoul_parking_8.columns = [['구', '유출인구수']]
seoul_Gu_inout = pd.merge(seoul_parking_7, seoul_parking_8)

def x(a,b):
    return a - b

seoul_Gu_inout['순유입인구수']  = seoul_Gu_inout.apply(lambda f: x(f['유입인구수'],f['유출인구수']), axis=1)
seoul_Gu_inout
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#        구   유입인구수   유출인구수  순유입인구수
# 0    종로구  287173   82692  204481
# 1     중구  329941   68167  261774
# 2    용산구  177143  124078   53065
# 3    성동구  201060  165458   35602
# 4    광진구  169073  202218  -33145
# 5   동대문구  210163  192914   17249
# 6    중랑구  142976  210478  -67502
# 7    성북구  218543  245708  -27165
# 8    강북구  109739  159847  -50108
# 9    도봉구  111704  171641  -59937
# 10   노원구  215080  284596  -69516
# 11   은평구  151103  254514 -103411
# 12  서대문구  193216  176994   16222
# 13   마포구  287134  213538   73596
# 14   양천구  176664  254009  -77345
# 15   강서구  310226  326875  -16649
# 16   구로구  239561  225899   13662
# 17   금천구  195820  131740   64080
# 18  영등포구  367547  213390  154157
# 19   동작구  179370  222297  -42927
# 20   관악구  190419  286144  -95725
# 21   서초구  395992  237245  158747
# 22   강남구  762766  300194  462572
# ...

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt
import numpy as np

plt.rc("font", family = "Malgun Gothic")
plt.rc("axes", unicode_minus = False)

plt.figure(figsize=(25,10))
plt.title('서울시 구별 통근통학 순유입인구수', size=20)

index = np.arange(seoul_Gu_inout.shape[0])
w = 0.5
k = seoul_Gu_inout['순유입인구수'].values.tolist()
klist = sum(k, [])
k2 = seoul_Gu_inout['구'].values.tolist()
klist2 = sum(k2, [])

plt.bar(index, klist, align='center', alpha=0.5)
plt.rcParams['axes.unicode_minus'] = False
plt.xticks(index, klist2)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

seoul_commute_out = seoul_parking_4[(seoul_parking_4['현거주지']=='서울특별시')]
seoul_commute_in = seoul_parking_4[(seoul_parking_4['통근통학지']=='서울특별시')]

plt.figure(figsize=(25,10))
plt.title('서울시 통근통학 인구수', size=20)

index = np.arange(seoul_commute_out.shape[0])
w = 0.3

plt.bar(index-w, seoul_commute_out['통근통학인구(12세 이상)'], width=w, color = ['b'], alpha = 0.4, label='서울에서 나가는 인구수')
plt.bar(index, seoul_commute_in['통근통학인구(12세 이상)'], width=w, color = ['r'], alpha = 0.4, label='서울에 들어오는 인구수')

plt.legend()
plt.xticks(index, seoul_parking_numcar['자치구별'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-a11377a1db29> in <module>
#      12
#      13 plt.bar(index-w, seoul_commute_out['통근통학인구(12세 이상)'], width=w, color = ['b'], alpha = 0.4, label='서울에서 나가는 인구수')
# ---> 14 plt.bar(index, seoul_commute_in['통근통학인구(12세 이상)'], width=w, color = ['r'], alpha = 0.4, label='서울에 들어오는 인구수')
#      15
#      16 plt.legend()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2405         x, height, width=0.8, bottom=None, *, align='center',
#    2406         data=None, **kwargs):
# -> 2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
#    2409         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
plt.figure(figsize=(15,10))
plt.title('통근통학지 인구수', size=20)

index = np.arange(seoul_commute.shape[0])
w = 0.5

plt.bar(index, seoul_commute['통근통학인구(12세 이상)'], color = ['orange'], alpha = 0.5)

plt.legend()
plt.xticks(index, seoul_commute['통행방향'])
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15,10))
plt.title('서울시 강서구 주차장', size=20)

seoul_parking_2 = seoul_parking.set_index('구별')
seoul_parking_gs = seoul_parking_2.T
seoul_parking_gs = seoul_parking_gs.reset_index()
seoul_parking_gs

x = seoul_parking_gs['index']
y = seoul_parking_gs['강서구']
plt.bar(x, y)

#seoul_parking_gs = seoul_parking[seoul_parking['구별']=='강서구']
#seoul_parking_gs = seoul_parking_gs.T
#seoul_parking_gs = seoul_parking_gs.iloc[1:,]
#seoul_parking_gs = seoul_parking_gs.reset_index()
#seoul_parking_gs

#plt.barh(seoul_parking_gs['index'], seoul_parking_gs['16'])
# Out:
# <BarContainer object of 8 artists>

# %%
label = ['합계(개소)', '합계(면수)', '노상(개소)', '노상(면수)', '노외(개소)', '노외(면수)', '건축물부설(개소)', '건축물부설(면수)']
index = np.arange(len(label))

plt.bar(index, seoul_parking_gs)
plt.xticks(index, label, fontsize=10)

plt.show()

label = ['노상(개소)', '노상(면수)', '노외(개소)', '노외(면수)', '건축물부설(개소)', '건축물부설(면수)']
index = np.arange(len(label))

plt.bar(index, seoul_parking_gs)
plt.xticks(index, label, fontsize=15)

plt.show()


plt.figure(figsize=(15,10))
plt.title('서울시 강서구 주차장', size=20)

index = np.arange(seoul_parking_gs.shape[1])
w = 0.25
a = seoul_parking_gs[['노상(개소)','노외(개소)','건축물부설(개소)']]
b = seoul_parking_gs[['노상(면수)','노외(면수)','건축물부설(면수)']]

plt.bar(index - w, a, width=w, label='주차장수')
plt.bar(index, b, width=w, label='주차장면적')

plt.legend()
plt.xticks(index, seoul_parking_1['구별'])
plt.show()
